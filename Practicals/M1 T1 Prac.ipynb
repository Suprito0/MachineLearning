# %% [markdown]
# # Module 1 Topic 1 Machine learning pipeline

# %% [markdown]
# ## Life satisfaction prediction
# This practice serves as your first introduction to machine learning this semester and ensures your development environment is properly set up. Today, you’ll run a simple linear regression model, but **don’t worry about understanding its details just yet** — we’ll cover linear regression in depth next week. For now, focus on understanding the input and output of the algorithm: the input `x` is GDP per capita (a numerical feature), and the output `y` is the predicted life satisfaction.
#
# In this exercise, you’ll explore how machine learning models can reveal patterns in real-world data. By training a linear regression model on a dataset linking GDP per capita to life satisfaction, you’ll see how the algorithm fits a line to the data to predict life satisfaction based on GDP. For example, the model will predict the life satisfaction for Cyprus, using its GDP per capita value, to demonstrate how machine learning makes data-driven predictions. Along the way, you’ll explore the data, visualize it, and test your understanding with practice questions and exercises.This code is your first step into machine learning this semester, designed not only to introduce you to key concepts but also to ensure your development environment is properly set up. It explores how machine learning can reveal intriguing patterns in real-world data by examining the relationship between a country’s GDP per capita and its citizens’ life satisfaction. Using pandas, we load and prepare the data, visualize the correlation with a scatter plot using matplotlib, and train a simple linear regression model with scikit-learn. As a practical example, the model predicts life satisfaction for Cyprus based on its GDP. This exercise ensures you have all the tools and libraries ready while offering an engaging introduction to the power of machine learning.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Download and prepare the data
data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# Visualize the data
lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

# Select a linear model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Make a prediction for Cyprus
X_new = [[37_655.2]]  # Cyprus' GDP per capita in 2020
print(model.predict(X_new)) # outputs [[6.30165767]]

# %% [markdown]
# ## Exercise 1
# Now it’s your turn to dive deeper! Take a closer look at the additional questions embedded in the code and try to solve them as you work through the example. These questions are designed to help you think critically about the data, the model’s behavior, and the insights we can draw from the results. Don’t worry if you don’t have all the answers right away—use this opportunity to explore, experiment, and familiarize yourself with the process. This hands-on practice will set the foundation for deeper learning in the coming weeks.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# Step 1: Download and prepare the data
data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

# %% [markdown]
# ## Question 1.1 (10 pts)
# Print the first 5 rows of the dataset to explore its structure.

# %%
#Printing the first 5 rows of the dataset
print(lifesat.head())

# %%
# Step 2: Visualize the data
lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()


# Step 3: Select and train a linear model
model = LinearRegression()
model.fit(X, y)

# Print the model's coefficients and intercept.
print("Model coefficients:", model.coef_)
print("Model intercept:", model.intercept_)

# Step 4: Make a prediction for Cyprus
X_new = [[37_655.2]]  # Cyprus' GDP per capita in 2020
prediction = model.predict(X_new)
print("Predicted life satisfaction for Cyprus:", prediction)

# %% [markdown]
# ## Question 1.2 (10 pts)
# Predict life satisfaction for another country with a GDP per capita of your choice.

# %%
# Making a prediction for Bangladesh
X_bd = [[2866]]  # Bangladesh' GDP per capita in Fiscal Year 2025–26 
prediction = model.predict(X_bd)
print("Predicted life satisfaction for Bangladesh:", prediction)

# %% [markdown]
# ## Question1.3 (30 pts)
# Please answer the following questions:
#
# 1. Question: What do you observe about the relationship between GDP and life satisfaction just by looking at the data?
#
# 1. Discuss: What are some limitations of using a linear model for this data? Could a more complex model perform better?
#
# Please enter your answer in the cell below.

# %% [markdown]
# 1. It looks like there is a positive correlation between GDP and life satisfation according to the graph. Countries with more GDP tend to be more satisfied with their life than countries with lower GDP.
#
# 2. Life satisfaction of a country does not solely depend on its GDP. There are several more factors such as healtcare, education, employment etc. A more complex model my be able to account for these and make a more accurate prediction.

# %% [markdown]
# ## Exercise 2
# In this exercise, you’ll explore how three different machine learning models—Linear Regression, Decision Tree Regressor, and K-Nearest Neighbors (KNN) Regressor—approach the same dataset in unique ways. Don’t worry about the details of how these algorithms work just yet; we’ll dive deeper into each method in future lessons. For now, focus on understanding the input-output relationship: the models take GDP per capita as input and predict life satisfaction as output. By visualizing the fits for all three models, you’ll see how their approaches differ and gain insight into their strengths and limitations. This exercise provides a hands-on introduction to model comparison and highlights how the choice of model impacts results.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# Step 1: Load the dataset
data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

#Preview the data
print("Dataset preview:")
print(lifesat.head())

# Step 2: Initialize three models
linear_model = LinearRegression()
tree_model = DecisionTreeRegressor(max_depth=3, random_state=42)
knn_model = KNeighborsRegressor(n_neighbors=5)

# Step 3: Train all models on the data
linear_model.fit(X, y)
tree_model.fit(X, y)
knn_model.fit(X, y)

#Print the models' scores on the training data
print("Linear Regression score:", linear_model.score(X, y))
print("Decision Tree score:", tree_model.score(X, y))
print("KNN Regressor score:", knn_model.score(X, y))

# Step 4: Generate predictions for visualization
X_plot = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
linear_predictions = linear_model.predict(X_plot)
tree_predictions = tree_model.predict(X_plot)
knn_predictions = knn_model.predict(X_plot)

# Step 5: Visualize the data and the model fits
plt.figure(figsize=(10, 6))

# Plot the original data
plt.scatter(X, y, color="black", label="Original data")

# Plot Linear Regression fit
plt.plot(X_plot, linear_predictions, color="blue", label="Linear Regression")

# Plot Decision Tree fit
plt.plot(X_plot, tree_predictions, color="green", label="Decision Tree")

# Plot KNN fit
plt.plot(X_plot, knn_predictions, color="red", label="KNN Regressor")

# Customize the plot
plt.xlabel("GDP per capita (USD)")
plt.ylabel("Life Satisfaction")
plt.title("Model Comparison: Linear Regression, Decision Tree, and KNN")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Question 2.1 (30 pts)
# Experiment with hyperparameters (e.g., max_depth for Decision Tree or n_neighbors for KNN) and observe how the fits change)

# %%
# Step 2: Initialize three models
linear_model = LinearRegression()
tree_model = DecisionTreeRegressor(max_depth=500, random_state=423)
knn_model = KNeighborsRegressor(n_neighbors=10)

# Step 3: Train all models on the data
linear_model.fit(X, y)
tree_model.fit(X, y)
knn_model.fit(X, y)

#Print the models' scores on the training data
print("Linear Regression score:", linear_model.score(X, y))
print("Decision Tree score:", tree_model.score(X, y))
print("KNN Regressor score:", knn_model.score(X, y))

# Step 4: Generate predictions for visualization
X_plot = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
linear_predictions = linear_model.predict(X_plot)
tree_predictions = tree_model.predict(X_plot)
knn_predictions = knn_model.predict(X_plot)

# Step 5: Visualize the data and the model fits
plt.figure(figsize=(10, 6))

# Plot the original data
plt.scatter(X, y, color="black", label="Original data")

# Plot Linear Regression fit
plt.plot(X_plot, linear_predictions, color="blue", label="Linear Regression")

# Plot Decision Tree fit
plt.plot(X_plot, tree_predictions, color="green", label="Decision Tree")

# Plot KNN fit
plt.plot(X_plot, knn_predictions, color="red", label="KNN Regressor")

# Customize the plot
plt.xlabel("GDP per capita (USD)")
plt.ylabel("Life Satisfaction")
plt.title("Model Comparison: Linear Regression, Decision Tree, and KNN")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Step 2: Initialize three models
linear_model = LinearRegression()
tree_model = DecisionTreeRegressor(max_depth=1, random_state=23)
knn_model = KNeighborsRegressor(n_neighbors=2)

# Step 3: Train all models on the data
linear_model.fit(X, y)
tree_model.fit(X, y)
knn_model.fit(X, y)

#Print the models' scores on the training data
print("Linear Regression score:", linear_model.score(X, y))
print("Decision Tree score:", tree_model.score(X, y))
print("KNN Regressor score:", knn_model.score(X, y))

# Step 4: Generate predictions for visualization
X_plot = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
linear_predictions = linear_model.predict(X_plot)
tree_predictions = tree_model.predict(X_plot)
knn_predictions = knn_model.predict(X_plot)

# Step 5: Visualize the data and the model fits
plt.figure(figsize=(10, 6))

# Plot the original data
plt.scatter(X, y, color="black", label="Original data")

# Plot Linear Regression fit
plt.plot(X_plot, linear_predictions, color="blue", label="Linear Regression")

# Plot Decision Tree fit
plt.plot(X_plot, tree_predictions, color="green", label="Decision Tree")

# Plot KNN fit
plt.plot(X_plot, knn_predictions, color="red", label="KNN Regressor")

# Customize the plot
plt.xlabel("GDP per capita (USD)")
plt.ylabel("Life Satisfaction")
plt.title("Model Comparison: Linear Regression, Decision Tree, and KNN")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Questions 2.2 (20 pts)
# Please discuss
#
# 1. Which model seems to capture the patterns in the data better, and why?
#
# 1. What are the advantages and disadvantages of each model for this dataset?
#
# Please enter your answers in the cell below

# %% [markdown]
# 1. KNN Regressor seems to capture the patterns in the data better. Linear Regression indicates the general upward trend but misses the non-linear patterns, and Decision Tree seems to get affected by outliers easily, showing abrupt changes. KNN Regressor looks like the only one that managed to capture the non-linear pattern smoothly.
#
#
# 2.
#
# Linear Regression:
#
#     Advantages:
#
#         Simple, easy to understand, easy to use, and useful for linear relations.
#
#     Disadvantages:
#
#         Bad for non-linear relations.
#
# Decision Tree:
#
#     Advantages:
#
#         Helpful for non-linear dataset and provides more accurate predictions compared to Linear Regression. Also, it's easy to understand.
#
#     Disadvantages:
#
#         Can be influenced by outliers which can cause overfitting.
#
# KNN Regressor:
#
#     Advantages:
#
#         Makes predictions for non-linear datasets based on nearest data points and makes good local predictions.
#
#     Disadvantages:
#
#         if n_neighbour is too small or big, it might cause prediction to be inaccurate due to overfitting and underfitting respectively. Bigger datasets will also cause it to slow down considerably.
